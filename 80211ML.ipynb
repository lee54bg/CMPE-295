# %%
import pandas as pd

# 7 frame_len
# 63 wlan_fc_type_subtype
# 65 wlan_fc_type
# 66 wlan_fc_subtype
# 67 wlan_fc_ds
# 68 wlan_fc_frag
# 69 wlan_fc_retry
# 74 wlan_duration
# 80 wlan_frag
# 153 data_len
# 154 classification

df = pd.read_csv('AWID-ATK-R-Trn/1.csv', header=0)
df.drop(df.columns[0], axis=1)
df = df.reset_index()

# %%
print(df.columns)
print(df["frame_len"].value_counts())
print(df["wlan_fc_type"].value_counts())
print(df["wlan_fc_subtype"].value_counts())
print(df["wlan_fc_ds"].value_counts())
print(df["wlan_fc_frag"].value_counts())
print(df["wlan_fc_retry"].value_counts())
print(df["wlan_duration"].value_counts())
print(df["data_len"].value_counts())
# print(df["classification"].nunique())
# print(df.dtypes)
# Out:
# Index(['index', 'Unnamed: 0', 'frame_len', 'wlan_fc_type', 'wlan_fc_subtype',
#        'wlan_fc_ds', 'wlan_fc_frag', 'wlan_fc_retry', 'wlan_duration',
#        'data_len', 'classification'],
#       dtype='object')
# 40      452821
# 1552    265889
# 1554    230933
# 56      222708
# 98      145035
# 124     123930
# 185      38668
# 128      30501
# 148      30409
# 159      27623
# 261      26855
# 54       18564
# 110      14642
# 60       12988
# 237      12762
# 172      11999
# 112      11475
# 1542      9974
# 142       8583
# 1524      7506
# 960       6972
# 136       5946
# 68        5278
# 179       4795
# 214       4238
# 132       3452
# 88        3324
# 99        3213
# 71        2708
# 255       2497
#          ...
# 926          1
# 1119         1
# 927          1
# 1320         1
# 1317         1
# 1135         1
# 1296         1
# 598          1
# 1278         1
# 1279         1
# 859          1
# 1286         1
# 862          1
# 1287         1
# 863          1
# ...

# %%
df = pd.get_dummies(df, prefix=[
    "wlan_fc_type",
    "wlan_fc_subtype",
    "wlan_fc_ds",
    "wlan_fc_frag",
    "wlan_fc_retry"], 
    columns=[
    "wlan_fc_type",
    "wlan_fc_subtype",
    "wlan_fc_ds",
    "wlan_fc_frag",
    "wlan_fc_retry"]
)

# %%
for i, c in enumerate(df):
    print(i, c)
# Out:
# 0 index
# 1 Unnamed: 0
# 2 frame_len
# 3 wlan_duration
# 4 data_len
# 5 classification
# 6 wlan_fc_type_0
# 7 wlan_fc_type_1
# 8 wlan_fc_type_2
# 9 wlan_fc_subtype_0
# 10 wlan_fc_subtype_1
# 11 wlan_fc_subtype_2
# 12 wlan_fc_subtype_3
# 13 wlan_fc_subtype_4
# 14 wlan_fc_subtype_5
# 15 wlan_fc_subtype_8
# 16 wlan_fc_subtype_9
# 17 wlan_fc_subtype_10
# 18 wlan_fc_subtype_11
# 19 wlan_fc_subtype_12
# 20 wlan_fc_subtype_13
# 21 wlan_fc_ds_0x00
# 22 wlan_fc_ds_0x01
# 23 wlan_fc_ds_0x02
# 24 wlan_fc_frag_0
# 25 wlan_fc_frag_1
# 26 wlan_fc_retry_0
# 27 wlan_fc_retry_1

# %%
y = df["classification"]
y = pd.get_dummies(y)
x = df.drop("classification", axis=1)

# x = x.as_matrix().astype(np.float)
# y = y.as_matrix().astype(np.float)
# Out:
# C:\Users\Amamiya\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """
# C:\Users\Amamiya\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
#x_test.fillna(x_test.mean())
#print(x_train)
#print(y_train)

# %%
# x_train.isna()

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

rfc = RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=1, n_jobs=2)

rfc.fit(x_train, y_train)

# Saving model to disk
pickle.dump(rfc, open('models/model.pkl','wb'))
print("Model Trained")

# import numpy as np
# print(type(y))
# print(y)
# np.unique(y)
# y.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-0c7fdc241183> in <module>
#       3 rfc = RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=1, n_jobs=2)
#       4
# ----> 5 x_train = x_train.as_matrix().astype(np.float)
#       6 y_train = y_train.as_matrix().astype(np.float)
#       7
#
# AttributeError: 'numpy.ndarray' object has no attribute 'as_matrix'
